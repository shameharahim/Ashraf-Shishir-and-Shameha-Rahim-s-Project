# %%
import pandas as pd 
import datetime as dt
import numpy as np 
import matplotlib.pyplot as plt
import pyodbc

# %%
lead_data = pd.read_csv('restaurants_data.csv')

# %%
boro_counts = lead_data["boro"].value_counts()

# %%
boro_counts.plot(kind="bar", title="Number of Restaurants by Borough", xlabel="Borough", ylabel="# of restaurants")
# Out:
# <AxesSubplot:title={'center':'Number of Restaurants by Borough'}, xlabel='Borough', ylabel='# of restaurants'>

# %%
zip_counts = lead_data["zipcode"].value_counts()

# %%
top_20_zip = zip_counts.head(20)

# %%
top_20_zip.plot(kind="bar", title="Most Popular Zipcodes for Restaurants", xlabel="Zip Code", ylabel="Number of Restaurants")
# Out:
# <AxesSubplot:title={'center':'Most Popular Zipcodes for Restaurants'}, xlabel='Zip Code', ylabel='Number of Restaurants'>

# %%
bttm_20_zip = zip_counts.tail(20)

# %%
bttm_20_zip.plot(kind="bar", title="Least Popular Zipcodes for Restaurants", xlabel="Zip Code", ylabel="Number of Restaurants")
# Out:
# <AxesSubplot:title={'center':'Least Popular Zipcodes for Restaurants'}, xlabel='Zip Code', ylabel='Number of Restaurants'>

# %%
vio_counts = lead_data["violation_code"].value_counts()

# %%
top_20_vio = vio_counts.head(20)

# %%
top_20_vio.plot(kind="bar", title="Most Common Violations", xlabel="Violation Code", ylabel="Number of times violation occured")
# Out:
# <AxesSubplot:title={'center':'Most Common Violations'}, xlabel='Violation Code', ylabel='Number of times violation occured'>

# %%
cuisine_counts = lead_data["cuisine_description"].value_counts()

# %%
top_20_cuisine = cuisine_counts.head(20)

# %%
top_20_cuisine.plot(kind="bar", title="Most Common Cuisine", xlabel="Cuisine Type", ylabel="Number of restaurants")
# Out:
# <AxesSubplot:title={'center':'Most Common Cuisine'}, xlabel='Cuisine Type', ylabel='Number of restaurants'>

# %%
bttm_20_cuisine = cuisine_counts.tail(20)

# %%
bttm_20_cuisine.plot(kind="bar", title="Least Common Cuisine", xlabel="Zip Code", ylabel="Number of Restaurants")
# Out:
# <AxesSubplot:title={'center':'Least Common Cuisine'}, xlabel='Zip Code', ylabel='Number of Restaurants'>

# %%
violation_key = lead_data[["violation_code", "violation_description"]].drop_duplicates()

# %%
violation_counts = lead_data["violation_description"].value_counts()

# %%
top_20_vio = violation_counts.head(20)

# %%
print(top_20_vio)
# Out:
# Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.                        39711
# Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.                                                                                                                                                                     23941
# Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.                                                                                                                                                         16159
# Evidence of mice or live mice present in facility's food and/or non-food areas.                                                                                                                                                                                                                        15596
# Food not protected from potential source of contamination during storage, preparation, transportation, display or service.                                                                                                                                                                             13776
# Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.                                                                                                                                                                       13435
# Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.                                                                     12990
# Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas.  Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies.  Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.    10622
# Hot food item not held at or above 140º F.                                                                                                                                                                                                                                                             10422
# Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.                                                                                                                                                                          5535
# Food Protection Certificate not held by supervisor of food operations.                                                                                                                                                                                                                                  4896
# Live roaches present in facility's food and/or non-food areas.                                                                                                                                                                                                                                          4854
# Proper sanitization not provided for utensil ware washing operation.                                                                                                                                                                                                                                    4082
# Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.                                                                                                                                                                                 4050
# Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.                                                                                                                                                                                                    4011
# Personal cleanliness inadequate. Outer garment soiled with possible contaminant. Effective hair restraint not worn in an area where food is prepared.                                                                                                                                                   3826
# Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2  hours, and from 70º F to 41º F or less within 4 additional hours.                                                                                                      3557
# Food contact surface not properly maintained.                                                                                                                                                                                                                                                           3262
# Wiping cloths soiled or not stored in sanitizing solution.                                                                                                                                                                                                                                              3083
# Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.                                               2699
# Name: violation_description, dtype: int64
